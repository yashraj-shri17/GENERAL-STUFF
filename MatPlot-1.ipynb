# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np #import matplotlib and numpy

# %%
xvals  = np.arange(0,10,0.1) #getiing random values from your range.

# %%
plt.plot(xvals , np.sin(xvals)) #plot function which takes random values as input and draw the graph of the value as  sin-suidal

# %%
plt.plot(xvals , np.sin(xvals))
plt.plot(xvals , np.cos(xvals))
plt.xlabel('x axis')
plt.ylabel('y axis') #xlabel or ylabel is used to give the names of x axis and y axis.
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.plot(xvals , np.sin(xvals),label = r"$y = \sin(x)$")
plt.plot(xvals , np.cos(xvals),label = r"$y = \cos(x)$")
plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis') #this label function is used to display the color of the  graph along the whatever you write in label function
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.plot(xvals , np.sin(xvals),label = r"$y = \sin(x)$",color = 'purple')
plt.plot(xvals , np.cos(xvals),label = r"$y = \cos(x)$",color = 'black')
plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis') #color function is used to change the color of the graph
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.plot(xvals , np.sin(xvals),label = r"$y = \sin(x)$",color = 'purple',linestyle = '--')
plt.plot(xvals , np.cos(xvals),label = r"$y = \cos(x)$",color = 'black',marker = 'o')
plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis')  #linestyle function will change the type of the line of the graph and so as marker.
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.plot(xvals , np.sin(xvals),'r+--',label = r"$y = \sin(x)$",color = 'purple')
plt.plot(xvals , np.cos(xvals),label = r"$y = \cos(x)$",color = 'black',marker = 'o')
plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis') #r+-- is way to write change the pattern of the graph line.
# Out:
# C:\Users\des\AppData\Local\Temp\ipykernel_18520\3669372354.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r+--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(xvals , np.sin(xvals),'r+--',label = r"$y = \sin(x)$",color = 'purple')
# Text(0, 0.5, 'y axis')

# %%
plt.plot(xvals , np.sin(xvals),'r+--',label = r"$y = \sin(x)$",color = 'purple')
plt.plot(xvals , np.cos(xvals),label = r"$y = \cos(x)$",color = 'black',marker = 'o')
plt.ylim(0,1)
plt.xlim(0,1)
plt.xlabel('x axis')
plt.ylabel('y axis')#xlim and ylim will change the xlim and ylim and will convert it into 0 to 1 .
# Out:
# C:\Users\des\AppData\Local\Temp\ipykernel_18520\1944029502.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r+--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(xvals , np.sin(xvals),'r+--',label = r"$y = \sin(x)$",color = 'purple')
# Text(0, 0.5, 'y axis')

# %%
rands = np.random.normal(size = 1000)
plt.hist(rands)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$") #hist function will convert the values and will make it a histogram.
# Out:
# Text(0, 0.5, '$y$')

# %%
from scipy.ndimage.filters import gaussian_filter
rands2d = gaussian_filter(np.random.normal(size=(512,512)),sigma = 10)
plt.imshow(rands2d)
plt.colorbar()
# Out:
# C:\Users\des\AppData\Local\Temp\ipykernel_18520\886179741.py:1: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter

# %%
#different line styles 
idx = 0
for marker in ('-','--',':','-.'):
    plt.plot(xvals , np.sin(xvals)+idx, ''.join(('k',marker)))
    idx+=1

# %%
plt.plot(xvals , np.sin(xvals),'r.',markersize = 4)
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)$')
# Out:
# Text(0, 0.5, '$\\sin(x)$')

# %%
#different markers
idx = 0
for marker in ('.',',','o','v','^','>','<','1','2','3'):
    plt.plot(idx , 0 ,''.join(('r',marker)))
    idx+=1
plt.xlim(-0.5,idx+0.5)
# Out:
# (-0.5, 10.5)

# %%
#Latex Marker
plt.plot(xvals , np.sin(xvals),color = 'k',linestyle = 'none',marker = r'$\sigma = \Sigma$')
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)$')
# Out:
# Text(0, 0.5, '$\\sin(x)$')

# %%
#line width
plt.plot(xvals , np.sin(xvals),linewidth = 10)
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)$')
# Out:
# Text(0, 0.5, '$\\sin(x)$')

# %%
#zorder
plt.plot(xvals, np.sin(xvals),lw = 8,zorder = 10)
plt.plot(xvals+1, np.sin(xvals),lw = 8,zorder = 1)
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)')
# Out:
# Text(0, 0.5, '$\\sin(x)')

# %%
#transparency
plt.plot(xvals, np.sin(xvals),lw = 8,zorder = 10,alpha = 0.5)
plt.plot(xvals+1, np.sin(xvals),lw = 8,zorder = 1,alpha = 0.5)
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)')
# Out:
# Text(0, 0.5, '$\\sin(x)')

# %%
#array order matters
shuffled_xvals = np.random.permutation(xvals)
plt.plot(shuffled_xvals,np.sin(shuffled_xvals),'k--')
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)')
# Out:
# Text(0, 0.5, '$\\sin(x)')

# %%
#Basic Scatter Plot
xvals = np.arange(0,10,0.1)
plt.scatter(xvals,np.sin(xvals))
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)$')
# Out:
# Text(0, 0.5, '$\\sin(x)$')

# %%
#colours in scatter
plt.scatter(xvals,np.sin(xvals),c=np.cos(xvals))
plt.colorbar()
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)$')
# Out:
# Text(0, 0.5, '$\\sin(x)$')

# %%
#colormaps
plt.scatter(xvals,np.sin(xvals),c=np.cos(xvals),cmap = 'inferno')
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)$')
# Out:
# Text(0, 0.5, '$\\sin(x)$')

# %%
#marker edge color
plt.scatter(xvals,np.sin(xvals),c=np.cos(xvals),edgecolor = 'none')
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)$')
# Out:
# Text(0, 0.5, '$\\sin(x)$')

# %%
#sizes
plt.scatter(xvals,np.sin(xvals),c=np.cos(xvals),s = np.power(xvals,3))
plt.xlabel(r'$x$')
plt.ylabel(r'$\sin(x)$')
# Out:
# Text(0, 0.5, '$\\sin(x)$')

# %%
#BASIC BAR PLOT
nums = np.random.uniform(size=10)
plt.bar(np.arange(10),height=nums)
# Out:
# <BarContainer object of 10 artists>

# %%
#horizontal bar plot
plt.barh(np.arange(10),width = nums)
# Out:
# <BarContainer object of 10 artists>

# %%
#bar color and edge color
plt.bar(np.arange(10),nums,color='limegreen',edgecolor='maroon')
# Out:
# <BarContainer object of 10 artists>

# %%
#bar alignment
plt.bar(np.arange(10),nums,align='center')
# Out:
# <BarContainer object of 10 artists>

# %%
#hatch and fill
plt.bar(np.arange(10),nums,hatch='x')
# Out:
# <BarContainer object of 10 artists>

# %%
#bar width
plt.bar(np.arange(10),nums,width=1)
# Out:
# <BarContainer object of 10 artists>

# %%
#edge color
plt.bar(np.arange(10),nums,width=1,edgecolor='black')
# Out:
# <BarContainer object of 10 artists>

# %%
#bottom allignment
plt.bar(np.arange(10),nums,bottom= 0.5*nums)
# Out:
# <BarContainer object of 10 artists>

# %%
#basic histogram
rands = np.random.normal(size = int(1e6))
plt.hist(rands);

# %%
#range
plt.hist(rands,range=(0,6));

# %%
#bin choice
plt.hist(rands,bins=[0,1,2]);

# %%
#histtype and normalization
plt.hist(rands,bins='auto',histtype='stepfilled');

# %%
#cumulative histogram
plt.hist(rands,bins='auto',cumulative=True);

# %%
#multiple hsitogram
plt.hist((rands,0.5*rands),bins='auto' , histtype='stepfilled' , stacked=True);

# %%
#Generating a smoothed ,  gaussian random field
from scipy.ndimage.filters import gaussian_filter
rands2d = gaussian_filter(np.random.normal(size=(512,512)),sigma = 10)
# Out:
# C:\Users\des\AppData\Local\Temp\ipykernel_18520\1908155359.py:2: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter

# %%
#Basic imshow
plt.imshow(rands2d)
plt.colorbar()

# %%
#Extent & LRBT
plt.imshow(rands2d , extent = [-1,1,-1,1])

# %%
#Min and Max
plt.imshow(rands2d , vmax = 0.5)
plt.colorbar()

# %%
#Aspect Ratio
plt.imshow(rands2d , aspect = 0.2)

# %%
#INTERPOLATION
small = np.arange(0,4,1).reshape(2,2)
plt.imshow(small,interpolation = 'nearest')

# %%
#Basic Contours
srands2d = gaussian_filter(rands2d, sigma = 100)
plt.contour(srands2d)
plt.colorbar()

# %%
#number of contours
plt.contour(srands2d,30)

# %%
#Contour colors
plt.contour(srands2d,30 , colors = ['r','b'])

# %%
#filled contour
plt.contourf(srands2d,10)

# %%
#Hatches
plt.contourf(srands2d,2,colors = 'none',hatches=['x','/'])

# %%
#Line styles and widths
plt.contour(srands2d,linestyles = [':','-','-'])

# %%
plt.contour(srands2d , color=['k'])
plt.imshow(srands2d)
# Out:
# C:\Users\des\AppData\Local\Temp\ipykernel_18520\2219785833.py:1: UserWarning: The following kwargs were not used by contour: 'color'
#   plt.contour(srands2d , color=['k'])

# %%
nums = np.arange(0,10,0.5)
xerrors = np.random.uniform(size = 20)
yerrors = np.random.uniform(size=20)

# %%
#errorbar color
plt.errorbar(nums , np.sin(nums),xerr = xerrors , yerr = yerrors , ecolor='red')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#errorbar capsize
plt.errorbar(nums , np.sin(nums),xerr = xerrors , yerr = yerrors , ecolor='red',capsize=5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(nums , np.sin(nums)**2,width=0.2)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.bar(nums , np.sin(nums)**2,width=0.2,xerr=xerrors,yerr=yerrors)
# Out:
# <BarContainer object of 20 artists>

# %%
#Fill
xvals = np.arange(0,10,0.1)
plt.fill(xvals , np.sin(xvals))

# %%
#Fill Color
plt.fill(xvals , np.sin(xvals),hatch='x')

# %%
#Fill Between
plt.fill_between(xvals,xvals+np.sin(xvals),np.sin(xvals)-xvals)

# %%
randx = np.random.normal(size = int(1e5))
randy = np.random.normal(size = int(1e5))

# %%
plt.plot(randx,randy,'k')

# %%
#Hexbin
plt.hexbin(randx,randy)

# %%
#Hist2d
plt.hist2d(randx,randy);

# %%
#SUBPLOT
nums = np.arange(0,10,0.1)
plt.subplot(1,2,1)
plt.plot(nums,np.sin(nums))
plt.subplot(1,2,2)
plt.plot(nums,np.cos(nums))

# %%
#SUBPLOT LABELS
plt.subplot(211)
plt.plot(nums,np.sin(nums))
plt.ylabel('sin')
plt.subplot(212)
plt.plot(nums,np.cos(nums))
plt.ylabel('cos')
# Out:
# Text(0, 0.5, 'cos')

# %%
#Subplots
fig , axes = plt.subplots(2,2)
print(axes.shape)
plt.clf()
# Out:
# (2, 2)

# %%
#looping with the axis array
fig,axes = plt.subplots(2,2)
i=1
for ax in axes.flatten():
    ax.plot(nums , np.power(np.sin(nums),i))
    i+=1

# %%
plt.plot(nums , np.sin(nums),label = 'sin')
plt.plot(nums , np.cos(nums),label = 'cos')
plt.plot(nums , np.tan(nums),label = 'tan')
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
#LOCATION
plt.plot(nums , np.sin(nums),label = 'sin')
plt.plot(nums , np.cos(nums),label = 'cos')
plt.plot(nums , np.tan(nums),label = 'tan')
plt.legend(loc = 'upper left')
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
#NUMBER OF COLUMNS
plt.plot(nums , np.sin(nums),label = 'sin')
plt.plot(nums , np.cos(nums),label = 'cos')
plt.plot(nums , np.tan(nums),label = 'tan')
plt.plot(nums , np.sinh(nums),label = 'sinh')
plt.plot(nums , np.cosh(nums),label = 'cosh')
plt.plot(nums , np.tanh(nums),label = 'tanh')
plt.legend(ncol=2)
plt.gcf().set_size_inches(6,2)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
#TITLE
plt.plot(nums , np.sin(nums),label = 'sin')
plt.plot(nums , np.cos(nums),label = 'cos')
plt.plot(nums , np.tan(nums),label = 'tan')
plt.plot(nums , np.sinh(nums),label = 'sinh')
plt.plot(nums , np.cosh(nums),label = 'cosh')
plt.plot(nums , np.tanh(nums),label = 'tanh')
plt.legend(ncol=2,title = 'Comparing Trigo Graphs')
plt.gcf().set_size_inches(6,2)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
#APPEARANCE 
plt.plot(nums , np.sin(nums),label = 'sin')
plt.plot(nums , np.cos(nums),label = 'cos')
plt.plot(nums , np.tan(nums),label = 'tan')
plt.legend(frameon = False)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
#APPEARANCE SHADOW
plt.plot(nums , np.sin(nums),label = 'sin')
plt.plot(nums , np.cos(nums),label = 'cos')
plt.plot(nums , np.tan(nums),label = 'tan')
plt.legend(shadow = True)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
#APPEARANCE Fancybox
plt.plot(nums , np.sin(nums),label = 'sin')
plt.plot(nums , np.cos(nums),label = 'cos')
plt.plot(nums , np.tan(nums),label = 'tan')
plt.legend(fancybox = True)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
#APPEARANCE Fontsize
plt.plot(nums , np.sin(nums),label = 'sin')
plt.plot(nums , np.cos(nums),label = 'cos')
plt.plot(nums , np.tan(nums),label = 'tan')
plt.legend(fontsize= 12)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
#Generated smoothed , gaussian random field
from scipy.ndimage.filters import gaussian_filter
rands2d = gaussian_filter(np.random.normal(size = (512,512)),sigma = 10)
# Out:
# C:\Users\des\AppData\Local\Temp\ipykernel_18520\1268845489.py:2: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter

# %%
plt.imshow(rands2d)
plt.colorbar()

# %%
#Orientation
plt.imshow(rands2d)
plt.colorbar(orientation = 'horizontal')

# %%
#Label
plt.imshow(rands2d)
cbar = plt.colorbar(orientation = 'horizontal')
cbar.set_label('Gaussian Random Field')

# %%
import numpy as np
import matplotlib
matplotlib.rcsetup.all_backends
# Out:
# ['GTK3Agg',
#  'GTK3Cairo',
#  'GTK4Agg',
#  'GTK4Cairo',
#  'MacOSX',
#  'nbAgg',
#  'QtAgg',
#  'QtCairo',
#  'Qt5Agg',
#  'Qt5Cairo',
#  'TkAgg',
#  'TkCairo',
#  'WebAgg',
#  'WX',
#  'WXAgg',
#  'WXCairo',
#  'agg',
#  'cairo',
#  'pdf',
#  'pgf',
#  'ps',
#  'svg',
#  'template']

# %%
matplotlib.use('TKAgg')

# %%
import matplotlib.pyplot as plt

# %%
xvals  = np.arange(0,10,0.1)
plt.plot(xvals , np.tan(xvals))
plt.show()

# %%
plt.plot(xvals , xvals)
plt.show()

# %%
#Non -Interactive Backend
import numpy as np
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
xvals = np.arange(0,101,0.1)
plt.plot(xvals , np.sin(xvals))
plt.savefig('example.png')

# %%
# !display example.png
# Out:
# 'display' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %matplotlib inline
#set up figure size and dpi for screen demo
plt.rcParams['figure.figsize'] = (4,3)
plt.rcParams['figure.dpi'] = 150

# %%
#GENERATE A FIGURE AND AXIS
fig = plt.figure()

# %%
#Resolution with dpi and figsize
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(1,1,'ro')

# %%
#trans data  (data -> display)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(1,1,'ro')
print(ax.transData.transform((1,1)))
plt.clf()
# Out:
# [600. 450.]

# %%
#trans Axes  (data -> display)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(1,1,'ro')
print(ax.transAxes.transform((1,1)))
plt.clf()
# Out:
# [600. 450.]

# %%
#trans Figures  (data -> display)
fig = plt.figure()
ax = fig.add_axes([0,0,0.5,1])
ax.plot(1,1,'ro')
print(ax.transFigure.transform((1,1)))
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 5
#       3 ax = fig.add_axes([0,0,0.5,1])
#       4 ax.plot(1,1,'ro')
# ----> 5 print(ax.transFigure.transform((1,1)))
#       6 plt.clf()
#
# AttributeError: 'Axes' object has no attribute 'transFigure'

# %%
#inverted transformation (display -> data)
fig = plt.figure()
ax = fig.add_axes([0,0,0.5,1])
ax.plot(1,1,'ro')
inv = ax.transData.inverted()
print(inv.transform((100,100)))
plt.clf()

# %%
#Frames with linewidth and edge color
fig = plt.figure(linewidth=10,edgecolor='r')
ax = fig.add_axes([0,0,1,1])

# %%
#Multiple Axes
fig = plt.figure()
ax = fig.add_axes([0,0,0.1,0.1])
ax = fig.add_axes([0,0.5,0.1,0.1])

# %%
#tight layout
plt.subplots(2,2);
plt.tight_layout()

# %%
#clearning figure and axis
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,0.5])
ax1.plot(range(0,10),range(0,10))
ax2 = fig.add_axes([0,0.5,1,0.5])
ax2.plot(range(0,10),range(0,10))

# %%
#Get cuurrent axis and figure
print(plt.gcf());
print(plt.gca());

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.yaxis

# %%
#GridLines
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.yaxis.grid(True)

# %%
#Location Of Axis
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.yaxis.set_ticks_position('right')

# %%
from matplotlib import ticker
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.xaxis.set_major_locator(ticker.MaxNLocator())

# %%
#Prune upper/lower tricks
from matplotlib import ticker
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.xaxis.set_major_locator(ticker.MaxNLocator(prune = 'both'))

# %%
#Integer Only Tricks
from matplotlib import ticker
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer = True))

# %%
#Manually selected ticks with FixedLocator
from matplotlib import ticker
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.xaxis.set_major_locator(ticker.FixedLocator([0.1,0.7,0.9]))

# %%
#Minor Ticks
from matplotlib import ticker
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.xaxis.set_minor_locator(ticker.MaxNLocator(20));

# %%
#Label Position
from matplotlib import ticker
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('ylabel')
ax.yaxis.set_label_position('right')

# %%
#Label Cooridnates
from matplotlib import ticker
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('y label')
ax.yaxis.label.set_y(0.5)

# %%
#Manually set tick Labels
index = ['one','two','three','four']
plt.plot()
plt.ylim(1,4)
plt.yticks([1,2,3,4])
# Out:
# ([<matplotlib.axis.YTick at 0x1631316bbd0>,
# ...
#  [Text(0, 1, '1'), Text(0, 2, '2'), Text(0, 3, '3'), Text(0, 4, '4')])

# %%
#Manually set tick Labels
index = ['one','two','three','four']
plt.plot()
plt.ylim(1,4)
plt.yticks([1,2,3,4],index)
# Out:
# ([<matplotlib.axis.YTick at 0x16313228d50>,
# ...
#  [Text(0, 1, 'one'),
#   Text(0, 2, 'two'),
#   Text(0, 3, 'three'),
#   Text(0, 4, 'four')])
